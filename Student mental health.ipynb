# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
smh = pd.read_csv('Student Mental health.csv')

# %%
smh
# Out:
#             Timestamp Choose your gender   Age What is your course?  \
# 0    08-07-2020 12:02             Female  18.0          Engineering
# 1    08-07-2020 12:04               Male  21.0    Islamic education
# 2    08-07-2020 12:05               Male  19.0                  BIT
# 3    08-07-2020 12:06             Female  22.0                 Laws
# 4    08-07-2020 12:13               Male  23.0         Mathemathics
# ..                ...                ...   ...                  ...
# 96   13-07-2020 19:56             Female  21.0                  BCS
# 97   13-07-2020 21:21               Male  18.0          Engineering
# 98   13-07-2020 21:22             Female  19.0             Nursing
# 99   13-07-2020 21:23             Female  23.0     Pendidikan Islam
# 100  18-07-2020 20:16               Male  20.0   Biomedical science
#
#     Your current year of Study What is your CGPA? Marital status  \
# 0                       year 1        3.00 - 3.49             No
# ...

# %%
smh.head()
# Out:
#           Timestamp Choose your gender   Age What is your course?  \
# 0  08-07-2020 12:02             Female  18.0          Engineering
# 1  08-07-2020 12:04               Male  21.0    Islamic education
# 2  08-07-2020 12:05               Male  19.0                  BIT
# 3  08-07-2020 12:06             Female  22.0                 Laws
# 4  08-07-2020 12:13               Male  23.0         Mathemathics
#
#   Your current year of Study What is your CGPA? Marital status  \
# 0                     year 1        3.00 - 3.49             No
# 1                     year 2        3.00 - 3.49             No
# 2                     Year 1        3.00 - 3.49             No
# 3                     year 3        3.00 - 3.49            Yes
# 4                     year 4        3.00 - 3.49             No
#
#   Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                     Yes                   No                       Yes
# ...

# %%
smh.head(20)
# Out:
#            Timestamp Choose your gender   Age What is your course?  \
# 0   08-07-2020 12:02             Female  18.0          Engineering
# 1   08-07-2020 12:04               Male  21.0    Islamic education
# 2   08-07-2020 12:05               Male  19.0                  BIT
# 3   08-07-2020 12:06             Female  22.0                 Laws
# 4   08-07-2020 12:13               Male  23.0         Mathemathics
# 5   08-07-2020 12:31               Male  19.0          Engineering
# 6   08-07-2020 12:32             Female  23.0     Pendidikan islam
# 7   08-07-2020 12:33             Female  18.0                  BCS
# 8   08-07-2020 12:35             Female  19.0      Human Resources
# 9   08-07-2020 12:39               Male  18.0                Irkhs
# 10  08-07-2020 12:39             Female  20.0           Psychology
# 11  08-07-2020 12:39             Female  24.0          Engineering
# 12  08-07-2020 12:40             Female  18.0                  BCS
# ...

# %%
smh.tail()
# Out:
#             Timestamp Choose your gender   Age What is your course?  \
# 96   13-07-2020 19:56             Female  21.0                  BCS
# 97   13-07-2020 21:21               Male  18.0          Engineering
# 98   13-07-2020 21:22             Female  19.0             Nursing
# 99   13-07-2020 21:23             Female  23.0     Pendidikan Islam
# 100  18-07-2020 20:16               Male  20.0   Biomedical science
#
#     Your current year of Study What is your CGPA? Marital status  \
# 96                      year 1        3.50 - 4.00             No
# 97                      Year 2        3.00 - 3.49             No
# 98                      Year 3        3.50 - 4.00            Yes
# 99                      year 4        3.50 - 4.00             No
# 100                     Year 2        3.00 - 3.49             No
#
#     Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 96                       No                  Yes                        No
# ...

# %%
smh.tail(20)
# Out:
#             Timestamp Choose your gender   Age What is your course?  \
# 81   13-07-2020 10:12             Female  24.0      Diploma Nursing
# 82   13-07-2020 10:12             Female  19.0          Engineering
# 83   13-07-2020 10:12             Female  19.0    Pendidikan Islam
# 84   13-07-2020 10:14               Male  23.0          Radiography
# 85   13-07-2020 10:33             Female  18.0           psychology
# 86   13-07-2020 10:34             Female  19.0          Fiqh fatwa
# 87   13-07-2020 11:46             Female  18.0           psychology
# 88   13-07-2020 11:49               Male  24.0                  BIT
# 89   13-07-2020 11:54               Male  24.0          Engineering
# 90   13-07-2020 13:57             Female  23.0         DIPLOMA TESL
# 91   13-07-2020 14:38               Male  18.0                  Koe
# 92   13-07-2020 14:48             Female  19.0                  KOE
# 93   13-07-2020 16:15             Female  18.0                 BENL
# ...

# %%
smh.shape
# Out:
# (101, 11)

# %%
smh.sample()
# Out:
#            Timestamp Choose your gender   Age What is your course?  \
# 83  13-07-2020 10:12             Female  19.0    Pendidikan Islam
#
#    Your current year of Study What is your CGPA? Marital status  \
# 83                     Year 2        3.00 - 3.49             No
#
#    Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 83                      No                   No                        No
#
#    Did you seek any specialist for a treatment?
# 83                                           No

# %%
smh.sample(10)
# Out:
#            Timestamp Choose your gender   Age What is your course?  \
# 88  13-07-2020 11:49               Male  24.0                  BIT
# 69  08-07-2020 19:32             Female  24.0                  Kop
# 29  08-07-2020 14:05             Female  24.0                  BCS
# 55  08-07-2020 15:58               Male  21.0                  BCS
# 57  08-07-2020 16:21             Female  20.0                 BENL
# 43  08-07-2020 15:07               Male   NaN                  BIT
# 63  08-07-2020 17:37             Female  24.0                engin
# 12  08-07-2020 12:40             Female  18.0                  BCS
# 20  08-07-2020 13:12             Female  19.0          Engineering
# 61  08-07-2020 16:53             Female  19.0                  BCS
#
#    Your current year of Study What is your CGPA? Marital status  \
# 88                     year 1        3.00 - 3.49             No
# 69                     year 4        3.00 - 3.49             No
# ...

# %%
smh.describe()
# Out:
#              Age
# count  100.00000
# mean    20.53000
# std      2.49628
# min     18.00000
# 25%     18.00000
# 50%     19.00000
# 75%     23.00000
# max     24.00000

# %%
smh.describe(include= 'object')
# Out:
#                Timestamp Choose your gender What is your course?  \
# count                101                101                  101
# unique                90                  2                   49
# top     13-07-2020 10:12             Female                  BCS
# freq                   3                 75                   18
#
#        Your current year of Study What is your CGPA? Marital status  \
# count                         101                101            101
# unique                          7                  6              2
# top                        year 1        3.50 - 4.00             No
# freq                           41                 47             85
#
#        Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# count                      101                  101                       101
# unique                       2                    2                         2
# ...

# %%
smh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 11 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Timestamp                                     101 non-null    object
#  1   Choose your gender                            101 non-null    object
#  2   Age                                           100 non-null    float64
#  3   What is your course?                          101 non-null    object
#  4   Your current year of Study                    101 non-null    object
#  5   What is your CGPA?                            101 non-null    object
#  6   Marital status                                101 non-null    object
#  7   Do you have Depression?                       101 non-null    object
#  8   Do you have Anxiety?                          101 non-null    object
# ...

# %%
smh.columns
# Out:
# Index(['Timestamp', 'Choose your gender', 'Age', 'What is your course?',
#        'Your current year of Study', 'What is your CGPA?', 'Marital status',
#        'Do you have Depression?', 'Do you have Anxiety?',
#        'Do you have Panic attack?',
#        'Did you seek any specialist for a treatment?'],
#       dtype='object')

# %%
smh.isnull().sum()
# Out:
# Timestamp                                       0
# Choose your gender                              0
# Age                                             1
# What is your course?                            0
# Your current year of Study                      0
# What is your CGPA?                              0
# Marital status                                  0
# Do you have Depression?                         0
# Do you have Anxiety?                            0
# Do you have Panic attack?                       0
# Did you seek any specialist for a treatment?    0
# dtype: int64

# %%
smh.dropna(inplace=True)
smh.isna().sum()
# Out:
# Timestamp                                       0
# Choose your gender                              0
# Age                                             0
# What is your course?                            0
# Your current year of Study                      0
# What is your CGPA?                              0
# Marital status                                  0
# Do you have Depression?                         0
# Do you have Anxiety?                            0
# Do you have Panic attack?                       0
# Did you seek any specialist for a treatment?    0
# dtype: int64

# %%
smh.isnull().sum()
# Out:
# Timestamp                                       0
# Choose your gender                              0
# Age                                             0
# What is your course?                            0
# Your current year of Study                      0
# What is your CGPA?                              0
# Marital status                                  0
# Do you have Depression?                         0
# Do you have Anxiety?                            0
# Do you have Panic attack?                       0
# Did you seek any specialist for a treatment?    0
# dtype: int64

# %%
columns_names = ['Timestamp', 'Gender', 'Age', 'Course',
       'Year of Study', 'CGPA', 'Is Married?',
       'Has Depression?', 'Has Anxiety?',
       'Has Panic attack?',
       'Is Undergoing treatment?']
smh.columns = columns_names
smh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 0 to 100
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Timestamp                 100 non-null    object
#  1   Gender                    100 non-null    object
#  2   Age                       100 non-null    float64
#  3   Course                    100 non-null    object
#  4   Year of Study             100 non-null    object
#  5   CGPA                      100 non-null    object
#  6   Is Married?               100 non-null    object
#  7   Has Depression?           100 non-null    object
#  8   Has Anxiety?              100 non-null    object
#  9   Has Panic attack?         100 non-null    object
#  10  Is Undergoing treatment?  100 non-null    object
# dtypes: float64(1), object(10)
# memory usage: 9.4+ KB

# %%
smh['Year of Study'].unique()
# Out:
# array(['year 1', 'year 2', 'Year 1', 'year 3', 'year 4', 'Year 2',
#        'Year 3'], dtype=object)

# %%
smh['Year of Study'] = smh['Year of Study'].str.split().str[1].astype(int)
smh['Year of Study'].unique()
# Out:
# array([1, 2, 3, 4])

# %%
smh
# Out:
#             Timestamp  Gender   Age              Course  Year of Study  \
# 0    08-07-2020 12:02  Female  18.0         Engineering              1
# 1    08-07-2020 12:04    Male  21.0   Islamic education              2
# 2    08-07-2020 12:05    Male  19.0                 BIT              1
# 3    08-07-2020 12:06  Female  22.0                Laws              3
# 4    08-07-2020 12:13    Male  23.0        Mathemathics              4
# ..                ...     ...   ...                 ...            ...
# 96   13-07-2020 19:56  Female  21.0                 BCS              1
# 97   13-07-2020 21:21    Male  18.0         Engineering              2
# 98   13-07-2020 21:22  Female  19.0            Nursing               3
# 99   13-07-2020 21:23  Female  23.0    Pendidikan Islam              4
# 100  18-07-2020 20:16    Male  20.0  Biomedical science              2
#
#             CGPA Is Married? Has Depression? Has Anxiety? Has Panic attack?  \
# ...

# %% [markdown]
# #### Student by Gender

# %%
smh['Gender'].value_counts()
# Out:
# Gender
# Female    75
# Male      25
# Name: count, dtype: int64

# %%
smh['Gender'].value_counts().plot(kind='pie', autopct = '%1.1f%%', explode = [0,0.05])
plt.title('Student by Gender', fontweight = 'bold')
plt.show()

# %% [markdown]
# #### Student year of study

# %%
smh['Year of Study'].value_counts()
# Out:
# Year of Study
# 1    42
# 2    26
# 3    24
# 4     8
# Name: count, dtype: int64

# %%
smh['Year of Study'].value_counts().plot(kind='bar', color=['tan','red','green','orange'])
plt.grid(c='k',ls=':')
plt.title('Student of Study', fontweight='bold')
plt.xlabel('Years')
plt.ylabel('Students')
plt.text(0,42.2,'42',c='k')
plt.text(1,26.2,'26',c='k')
plt.text(2,24.2,'24',c='k')
plt.text(3,8.2,'8',c='k')
plt.show()

# %% [markdown]
# #### Student CGPA

# %%
plt.figure(figsize=(12,6))
sns.histplot(smh['CGPA'].sort_values(),kde=True)
plt.title('Student by CGPA', fontweight='bold')
plt.ylabel('Student')
plt.grid(ls=':')
plt.show()

# %% [markdown]
# #### Age by Student

# %%
smh['Age'].value_counts()
# Out:
# Age
# 18.0    32
# 24.0    23
# 19.0    21
# 23.0    13
# 20.0     6
# 21.0     3
# 22.0     2
# Name: count, dtype: int64

# %%
sns.countplot(data=smh, x='Age')
plt.xlabel('Age')
plt.ylabel('Students')
plt.title('Age by Students', fontsize=12, fontweight='bold')
plt.grid(ls=':',c='k')
plt.text(0,32.3,'32')
plt.text(1,21.3,'21.3')
plt.text(2,6.3,'6')
plt.text(3,3.3,'3')
plt.text(4,2.3,'2')
plt.text(5,13.3,'13')
plt.text(6,23.3,'23')
plt.show()

# %% [markdown]
# #### Exploratory Data Analysis

# %% [markdown]
# #### Student Conditions

# %%
depressed_filter = smh['Has Depression?'] == 'Yes'
anxiety_filter = smh['Has Anxiety?'] == 'Yes'
panicking_filter = smh['Has Panic attack?'] == 'Yes'
conditions_filter = anxiety_filter | depressed_filter | panicking_filter
no_condition_filter = depressed_filter & anxiety_filter & panicking_filter

# %%
smh['Has Condition?'] = np.where(conditions_filter, 'Yes',"No")
smh
# Out:
#             Timestamp  Gender   Age              Course  Year of Study  \
# 0    08-07-2020 12:02  Female  18.0         Engineering              1
# 1    08-07-2020 12:04    Male  21.0   Islamic education              2
# 2    08-07-2020 12:05    Male  19.0                 BIT              1
# 3    08-07-2020 12:06  Female  22.0                Laws              3
# 4    08-07-2020 12:13    Male  23.0        Mathemathics              4
# ..                ...     ...   ...                 ...            ...
# 96   13-07-2020 19:56  Female  21.0                 BCS              1
# 97   13-07-2020 21:21    Male  18.0         Engineering              2
# 98   13-07-2020 21:22  Female  19.0            Nursing               3
# 99   13-07-2020 21:23  Female  23.0    Pendidikan Islam              4
# 100  18-07-2020 20:16    Male  20.0  Biomedical science              2
#
#             CGPA Is Married? Has Depression? Has Anxiety? Has Panic attack?  \
# ...

# %%
smh['Condition'] = ''
smh.loc[anxiety_filter, 'Condition'] += 'A'
smh.loc[depressed_filter, 'Condition'] += 'D'
smh.loc[panicking_filter, 'Condition'] += 'P'
smh.loc[no_condition_filter, 'Condition'] += 'None'
smh
# Out:
#             Timestamp  Gender   Age              Course  Year of Study  \
# 0    08-07-2020 12:02  Female  18.0         Engineering              1
# 1    08-07-2020 12:04    Male  21.0   Islamic education              2
# 2    08-07-2020 12:05    Male  19.0                 BIT              1
# 3    08-07-2020 12:06  Female  22.0                Laws              3
# 4    08-07-2020 12:13    Male  23.0        Mathemathics              4
# ..                ...     ...   ...                 ...            ...
# 96   13-07-2020 19:56  Female  21.0                 BCS              1
# 97   13-07-2020 21:21    Male  18.0         Engineering              2
# 98   13-07-2020 21:22  Female  19.0            Nursing               3
# 99   13-07-2020 21:23  Female  23.0    Pendidikan Islam              4
# 100  18-07-2020 20:16    Male  20.0  Biomedical science              2
#
#             CGPA Is Married? Has Depression? Has Anxiety? Has Panic attack?  \
# ...

# %%
smh = smh[smh['Has Condition?'] == 'Yes']

# %%
total_entries = len(smh)
percentage_depression = (smh['Has Depression?'].value_counts()['Yes'] / total_entries) * 100
percentage_anxiety = (smh['Has Anxiety?'].value_counts()['Yes'] / total_entries) * 100
percentage_panic_attack = (smh['Has Panic attack?'].value_counts()['Yes'] / total_entries) * 100

sizes = [percentage_depression,percentage_anxiety,percentage_panic_attack]
plt.pie(sizes, explode=(0.02,0.01,0.01), labels=['Depression','Anxiety','Panic Attack'], autopct='%1.1f%%')

plt.title('Percentage of each condition', fontsize= 12, fontweight='bold')

plt.show()

# %% [markdown]
# #### Under going treatment

# %%
labels = ['Not Undergoing Treatment','Undergoing Treatment']

plt.pie(smh['Is Undergoing treatment?'].value_counts(),labels= labels, autopct='%1.1f%%', explode=(0.05,0.005),startangle=180)
plt.title('Student Undergoing Treatement', fontsize=12, fontweight='bold')
plt.show()

# %%
sort = smh['Condition'].value_counts().index.tolist()

# %%
sns.countplot(data=smh, x='Condition',hue='Is Undergoing treatment?', order=sort)
plt.xlabel('Condition')
plt.ylabel('Students')
plt.title('Student Undergoing Treatement', fontsize=12, fontweight='bold')
plt.show()

# %% [markdown]
# #### Student by Gender

# %%
sns.countplot(data=smh, x='Condition', hue='Gender', order=sort)
plt.xlabel('Condition')
plt.ylabel('Students')
plt.title('Student by Gender', fontsize=12, fontweight='bold')
plt.show()
